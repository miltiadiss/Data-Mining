# %% [markdown]
# <a href="https://colab.research.google.com/github/miltiadiss/Data-Mining/blob/main/question_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ερώτημα 2**

# %%
import os
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

def create_lags(df, lag):
    cols_to_shift = [col for col in df.columns if (col != 'timestamp' and col != 'label')]
    lagged_data = {f'{col}_lag_{i}': df[col].shift(i) for col in cols_to_shift for i in range(1, lag + 1)}
    lagged_df = pd.DataFrame(lagged_data)
    df = pd.concat([df, lagged_df], axis=1)
    df.fillna(0, inplace=True)  # Αντικατάσταση των τιμών NaN με 0
    return df

# Ορίστε τον φάκελο που περιέχει τα αρχεία CSV
path = '/content/drive/MyDrive/harth'

# %% [markdown]
# **Random Forest**

# %%
rf_accuracies = []  # Λίστα για την αποθήκευση των ακριβειών από κάθε αρχείο
rf_precisions = []  # Λίστα για την αποθήκευση των precisions από κάθε αρχείο
rf_recalls = []     # Λίστα για την αποθήκευση των recalls από κάθε αρχείο
rf_f1_scores = []   # Λίστα για την αποθήκευση των f1-scores από κάθε αρχείο

# Δημιουργούμε και εκπαιδεύουμε τον ταξινομητή Random Forest
rf_classifier = RandomForestClassifier(n_estimators=30, random_state=42)

# Διατρέχουμε τα αρχεία στον φάκελο
for filename in os.listdir(path):
    if filename.endswith(".csv"):
        # Φορτώνουμε το CSV αρχείο
        df = pd.read_csv(os.path.join(path, filename))

        # Δημιουργούμε τα lags
        df = create_lags(df, 50)

        # Διαχωρίζουμε σε train και test sets
        train_size = int(0.8 * len(df))
        train_df = df.iloc[:train_size]
        test_df = df.iloc[train_size:]

        X_train = train_df.drop(['timestamp', 'label'], axis=1)
        y_train = train_df['label']
        X_test = test_df.drop(['timestamp', 'label'], axis=1)
        y_test = test_df['label']

        rf_classifier.fit(X_train, y_train)

        # Προβλέπουμε τις ετικέτες του test set
        y_pred = rf_classifier.predict(X_test)

        # Υπολογίζουμε τις μετρικές
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, average='weighted')
        recall = recall_score(y_test, y_pred, average='weighted')
        f1 = f1_score(y_test, y_pred, average='weighted')

        # Προσθήκη των μετρικών στις λίστες
        rf_accuracies.append(accuracy)
        rf_precisions.append(precision)
        rf_recalls.append(recall)
        rf_f1_scores.append(f1)

        # Εκτύπωση των μετρικών για κάθε αρχείο
        base_name = os.path.splitext(filename)[0] # Χωρίς κατάληξη
        print(f"Metrics for Participant {base_name}:")
        print(f"  Accuracy: {accuracy}")
        print(f"  Precision: {precision}")
        print(f"  Recall: {recall}")
        print(f"  F1-Score: {f1}")

        # Υπολογισμός και εμφάνιση του confusion matrix
        unique_labels = sorted(y_test.unique())
        cm = confusion_matrix(y_test, y_pred, labels=unique_labels)
        plt.figure(figsize=(10, 7))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels, yticklabels=unique_labels)
        plt.title(f'Confusion Matrix for Participant {base_name}')
        plt.xlabel('Predicted Labels')
        plt.ylabel('True Labels')
        plt.show()

# Υπολογισμός της μέσης τιμής για κάθε μετρική
mean_accuracy = sum(rf_accuracies) / len(rf_accuracies)
mean_precision = sum(rf_precisions) / len(rf_precisions)
mean_recall = sum(rf_recalls) / len(rf_recalls)
mean_f1 = sum(rf_f1_scores) / len(rf_f1_scores)

print(f"Mean Metrics of All Participants:")
print(f"  Mean Accuracy: {mean_accuracy}")
print(f"  Mean Precision: {mean_precision}")
print(f"  Mean Recall: {mean_recall}")
print(f"  Mean F1-Score: {mean_f1}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S017.csv:
#   Accuracy: 0.6992307902130329
#   Precision: 0.6676784953935434
#   Recall: 0.6992307902130329
#   F1-Score: 0.6677628638948414
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S009.csv:
#   Accuracy: 0.9176188780629916
#   Precision: 0.9104447391702519
#   Recall: 0.9176188780629916
#   F1-Score: 0.9120348881167766
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S016.csv:
#   Accuracy: 0.7282932868155985
#   Precision: 0.6351982211398838
#   Recall: 0.7282932868155985
#   F1-Score: 0.6680731118613662
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S021.csv:
#   Accuracy: 0.7925062034739454
#   Precision: 0.7496219636309767
#   Recall: 0.7925062034739454
#   F1-Score: 0.7554390945625966
# Metrics for Participant S010.csv:
#   Accuracy: 0.8607848713209156
#   Precision: 0.870296227997705
#   Recall: 0.8607848713209156
#   F1-Score: 0.8236508957484419
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S028.csv:
#   Accuracy: 0.995429228720184
#   Precision: 0.9956686725090882
#   Recall: 0.995429228720184
#   F1-Score: 0.9948742153518699
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S015.csv:
#   Accuracy: 0.7937714360831272
#   Precision: 0.7319555843709118
#   Recall: 0.7937714360831272
#   F1-Score: 0.7471728758185494
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S026.csv:
#   Accuracy: 0.8233124119380043
#   Precision: 0.8069392571396864
#   Recall: 0.8233124119380043
#   F1-Score: 0.8048894427865683
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S029.csv:
#   Accuracy: 0.9850324529991047
#   Precision: 0.9874839503839407
#   Recall: 0.9850324529991047
#   F1-Score: 0.9862401046567194

# %% [markdown]
# **Neural Network**

# %%
import numpy as np
import tensorflow as tf

# Lists to store metrics
ann_accuracies = []  # Λίστα για την αποθήκευση των ακριβειών από κάθε αρχείο
ann_precisions = []  # Λίστα για την αποθήκευση των precisions από κάθε αρχείο
ann_recalls = []     # Λίστα για την αποθήκευση των recalls από κάθε αρχείο
ann_f1_scores = []   # Λίστα για την αποθήκευση των f1-scores από κάθε αρχείο

# Loop through the files in the folder
for filename in os.listdir(path):
    if filename.endswith(".csv"):
        # Load the CSV file
        df = pd.read_csv(os.path.join(path, filename))

        # Create lag features
        df = create_lags(df, 50)

        # Split into train and test sets
        train_size = int(0.8 * len(df))
        train_df = df.iloc[:train_size]
        test_df = df.iloc[train_size:]

        X_train = train_df.drop(['timestamp', 'label'], axis=1)
        y_train = train_df['label']
        X_test = test_df.drop(['timestamp', 'label'], axis=1)
        y_test = test_df['label']

        # Encode labels
        y_train = tf.keras.utils.to_categorical(y_train)
        y_test = tf.keras.utils.to_categorical(y_test)

        # Initialize ANN
        ann = tf.keras.models.Sequential()
        # Adding first hidden layer
        ann.add(tf.keras.layers.Dense(units=50, activation="relu", input_shape=(X_train.shape[1],)))
        # Adding second hidden layer
        ann.add(tf.keras.layers.Dense(units=50, activation="relu"))
        # Adding output layer
        ann.add(tf.keras.layers.Dense(units=y_train.shape[1], activation="softmax"))

        # Compiling ANN
        ann.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])

        # Fitting ANN
        ann.fit(X_train, y_train, batch_size=32, epochs=50, verbose=0)

        # Making predictions
        y_pred = ann.predict(X_test)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_test_classes = np.argmax(y_test, axis=1)

        # Calculate accuracy and other metrics
        accuracy = accuracy_score(y_test_classes, y_pred_classes)
        precision = precision_score(y_test_classes, y_pred_classes, average='weighted')
        recall = recall_score(y_test_classes, y_pred_classes, average='weighted')
        f1 = f1_score(y_test_classes, y_pred_classes, average='weighted')

        # Append metrics to lists
        ann_accuracies.append(accuracy)
        ann_precisions.append(precision)
        ann_recalls.append(recall)
        ann_f1_scores.append(f1)

        # Print metrics for each file
        base_name = os.path.splitext(filename)[0] # Χωρίς κατάληξη
        print(f"Metrics for Participant {base_name}:")
        print(f"  Accuracy: {accuracy}")
        print(f"  Precision: {precision}")
        print(f"  Recall: {recall}")
        print(f"  F1-Score: {f1}")

        # Plot confusion matrix
        unique_labels = sorted(df['label'].unique())
        cm = confusion_matrix(y_test_classes, y_pred_classes)
        plt.figure(figsize=(10, 7))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels, yticklabels=unique_labels)
        plt.title(f'Confusion Matrix for Participant {base_name}')
        plt.xlabel('Predicted Labels')
        plt.ylabel('True Labels')
        plt.show()

# Calculate and print mean metrics
mean_accuracy = np.mean(ann_accuracies)
mean_precision = np.mean(ann_precisions)
mean_recall = np.mean(ann_recalls)
mean_f1 = np.mean(ann_f1_scores)

print("Mean Metrics of All Participants:")
print(f"  Mean Accuracy: {mean_accuracy}")
print(f"  Mean Precision: {mean_precision}")
print(f"  Mean Recall: {mean_recall}")
print(f"  Mean F1-Score: {mean_f1}")
# Out:
# 2292/2292 [==============================] - 3s 1ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S017.csv:
#   Accuracy: 0.6747088186356073
#   Precision: 0.6704307046760759
#   Recall: 0.6747088186356073
#   F1-Score: 0.6631747718627455
# 966/966 [==============================] - 1s 1ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S009.csv:
#   Accuracy: 0.8632699964393228
#   Precision: 0.8752186742798044
#   Recall: 0.8632699964393228
#   F1-Score: 0.8656830990905254
# 2222/2222 [==============================] - 3s 1ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S016.csv:
#   Accuracy: 0.6777193179899836
#   Precision: 0.6473078959804689
#   Recall: 0.6777193179899836
#   F1-Score: 0.65424186414198
# 1890/1890 [==============================] - 2s 1ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S021.csv:
#   Accuracy: 0.7321422663358147
#   Precision: 0.536032298155343
#   Recall: 0.7321422663358147
#   F1-Score: 0.6189241017589961
# 2198/2198 [==============================] - 2s 1ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S010.csv:
#   Accuracy: 0.8500355467083748
#   Precision: 0.8666055677727986
#   Recall: 0.8500355467083748
#   F1-Score: 0.8287760059015906
# 1033/1033 [==============================] - 1s 1ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics for Participant S028.csv:
#   Accuracy: 0.9962465189490253
#   Precision: 0.9971296830361319
#   Recall: 0.9962465189490253
#   F1-Score: 0.9963734868731847
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f9e87c7055e4> in <cell line: 11>()
#      44
#      45         # Fitting ANN
# ---> 46         ann.fit(X_train, y_train, batch_size=32, epochs=50, verbose=0)
#      47
#      48         # Making predictions
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1796                 callbacks.on_epoch_begin(epoch)
#    1797                 with data_handler.catch_stop_iteration():
# -> 1798                     for step in data_handler.steps():
#    1799                         with tf.profiler.experimental.Trace(
#    1800                             "train",
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in steps(self)
#    1409             if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1410                 break
# -> 1411             original_spe = self._steps_per_execution.numpy().item()
#    1412             can_run_full_execution = (
#    1413                 original_spe == 1
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in numpy(self)
#     687   def numpy(self):
#     688     if context.executing_eagerly():
# --> 689       return self.read_value().numpy()
#     690     raise NotImplementedError(
#     691         "numpy() is only available when eager execution is enabled.")
#
# KeyboardInterrupt:

# %% [markdown]
# **Bayesian Network**
